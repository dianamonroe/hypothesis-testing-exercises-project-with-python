# %% [markdown]
# # Hypothesis testing problems

# %% [markdown]
# ## Exercise 1
#
# You are a nutritionist researching two different types of diets to see if there is a significant difference in weight loss after one month. You choose two random groups of people; one group follows the first diet, and the other follows the second. At the end of the month, you record the weight loss (in kg) for each person:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# With these data, it seeks to answer the following question: Is there a significant difference in average weight loss between people who followed the first diet and those who followed the second diet?
#
# To draw conclusions, follow the points below:
#
# - State the hypothesis: null and alternative hypothesis.
# - Perform the test to test the hypothesis. You can use a Student's t-test.
# - Analyze the conclusions.

# %%
#H0 = no hay una diferencia significativa en la pérdida de peso promedio entre las 2 dietas 
#H0 => µ1 = µ2 (la media poblacional del conjunto de datos 1 es igual al conjunto de datos 2) 
#H1 => µ1 ≠µ2 ( la media poblacional del conjunto de datos 1 es diferente de la del conjunto de datos 2) 
#H1 = hay una diferencia significativa en la pérdida de peso promedio entre las 2 dietas


import numpy as np
import scipy.stats as stats

diet_1 = np.array([2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5])
diet_2 = np.array([3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2])

mean_diet_1 = np.mean(diet_1)
mean_diet_2 = np.mean(diet_2)

print("Mean diet 1: ", round(mean_diet_1, 4))
print("Mean diet 2: ", round(mean_diet_2, 4))

print(np.var(diet_1), np.var(diet_2))

result1 = np.var(diet_2) / np.var(diet_1)
result2 = 4/1

print(result1)
print(result2)

# the ratio of variances is less than 4:1

# Performing a two-sample t-test
#equal_var = “True”: Welch's t-test will be performed without taking into account equal population variances.

#Perform the two sample t-test with equal variances
#A) Assuming the corelation between the variances is smaller than 4:1
t_value, p_value = stats.ttest_ind(a=diet_1, b=diet_2, equal_var=True)

alpha = 0.05

print("t_value: ", t_value)
print("p_value: ", p_value)

print(f'Since the variance between samples is less than {result2}, {round(result1, 2)*100}, we assume equal_vale=True in the t-test formula')
print("We reject H0") if (p_value - alpha) < 0 else print("We cannot reject H0")
print(f'Since the p-value ({p_value}%) is below the margin of error (alpha) {alpha}%: ')
print(f'This is because with diet 2, on average, weight lost is almost half a kilo higher ({round(mean_diet_2 - mean_diet_1, 4)}kg) of than diet 1, a significant difference between both diets as indicated by the p-value')
# Out:
# Mean diet 1:  2.5429
# Mean diet 2:  3.0286
# 0.09387755102040818 0.01918367346938779
# 0.20434782608695687
# 4.0
# t_value:  -3.5383407969933938
# p_value:  0.004083270191713912
# Since the variance between samples is less than 4.0, 20.0, we assume equal_vale=True in the t-test formula
# We reject H0
# Since the p-value (0.004083270191713912%) is below the margin of error (alpha) 0.05%:
# This is because with diet 2, on average, weight lost is almost half a kilo higher (0.4857kg) of than diet 1, a significant difference between both diets as indicated by the p-value

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance*) is a statistical technique used to compare the measures of two or more groups. The idea behind ANOVA is to decompose the total variability in the data into two components: between-group variability and within-group variability:
#
# - **Between-group variability**: This variability refers to the differences between the group means. If this variability is considerably larger than the within-group variability, it could be an indication that at least one of the group means is different.
# - **Within-group variability**: This variability refers to the dispersion of the data within each group. If all groups have similar variability, then any noticeable difference in group means could be considered significant.
#
# Hypotheses in ANOVA typically include:
#
# - **Null hypothesis** ($H₀$): The means of all groups are equal.
# - **Alternative hypothesis** ($H₁$): At least one of the group means is different.
#
# If the ANOVA test result is significant (e.g., a p-value less than a threshold such as 0.05), this suggests that at least one group mean is different.

# %% [markdown]
# ## Exercise 2
#
# A farmer decides to test three different types of fertilizers to determine if one is superior in terms of corn production. The farmer plants corn on 15 identical plots and uses all three fertilizers (5 plots for each type). At the end of the season, he measures the corn yield (in kg) of each plot, with the following result:
#
# | Fertilizer 1 | Fertilizer 2 | Fertilizer 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# With this data, he seeks to answer the following question: Is there a significant difference in average corn yield between the three types of fertilizers?
#
# To help you, follow the points below:
#
# - State the hypothesis: null and alternative hypothesis.
# - Perform the ANOVA test.
# - Analyze the conclusions.
# - If one fertilizer is better than another, how can we know it?

# %%
import numpy as np
from scipy.stats import f_oneway

import numpy as np
import pandas as pd

#H0 (null hypothesis): μ1 = μ2 = μ3 = … = μk (Implies that the means of the entire population are equal)
#H1 (null hypothesis): Establishes that there will be at least one population mean that differs from the rest.

data = [[20, 22, 24],
        [21, 21, 23],
        [20, 23, 22],
        [19, 22, 23],
        [20, 21, 24]]

fertilizer1 = np.array([row[0] for row in data])
fertilizer2 = np.array([row[1] for row in data])
fertilizer3 = np.array([row[2] for row in data])

mean_fert1 = np.mean(fertilizer1)
mean_fert2 = np.mean(fertilizer2)
mean_fert3 = np.mean(fertilizer3)

alpha = 0.05

t_statistics, p_value = f_oneway(fertilizer1, fertilizer2, fertilizer3)

print(f"The F statistic is {round(t_statistics, 6)} and the p_value is {round(p_value,6)}%, which is considerably less than alpha {alpha}")
print("Conclusion: We reject H0") if (p_value - alpha) < 0 else print("Conclusion: We cannot reject H0")
print(f'More specifically, fertilizer 3 achieves on average {round((mean_fert3-mean_fert1),4)}cm higher plant growth \
than fertilizer 1 and {round((mean_fert3-mean_fert2),4)}cm more than fertilizer 2, a significant difference based on the small p-value')
# Out:
# The F statistic is 20.315789 and the p_value is 0.00014%, which is considerably less than alpha 0.05
# Conclusion: We reject H0
# More specifically, fertilizer 3 achieves on average 3.2cm higher plant growth than fertilizer 1 and 1.4cm more than fertilizer 2, a significant difference based on the small p-value

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd


data = np.concatenate([fertilizer1, fertilizer2, fertilizer3])

labels = ["F1"] * 5 + ["F2"] * 5 + ["F3"] * 5


fertilizer_comparsion = pairwise_tukeyhsd(data, labels, alpha = 0.05)

print(fertilizer_comparsion)
print("In a more in-depth comparsion análisis using post-hoc Pairwise Tukeyhs test, we find 'True' all the 'reject' columns (meaning the H0 hypotesis should be rejected), so there is significance difference in paired comparsion between all the fertilizers")
print("More specifically and based on the higher and positive value of meandiff, all fertilizers differ significantly from each other. The third fertilizer has the highest average, followed by the second and ending with the first. Therefore, **according to these results, the third fertilizer would be the best**.")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#     F1     F2      1.8 0.0099 0.4572 3.1428   True
#     F1     F3      3.2 0.0001 1.8572 4.5428   True
#     F2     F3      1.4 0.0409 0.0572 2.7428   True
# --------------------------------------------------
# In a more in-depth comparsion análisis using post-hoc Pairwise Tukeyhs test, we find 'True' all the 'reject' columns (meaning the H0 hypotesis should be rejected), so there is significance difference in paired comparsion between all the fertilizers
# More specifically and based on the higher and positive value of meandiff, all fertilizers differ significantly from each other. The third fertilizer has the highest average, followed by the second and ending with the first. Therefore, **according to these results, the third fertilizer would be the best**.
